# %% [markdown]
# ## project

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#     print(item)
# ```

# %%
print("hi ybi foundation")
# Out:
# hi ybi foundation

# %% [markdown]
# image

# %% [markdown]
# ![WallpaperDog-5502365.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# adding two NUMBERS

# %%
24+37
# Out:
# 61

# %% [markdown]
# ### creatintig link

# %% [markdown]
# [google search](https://www.google.com)

# %% [markdown]
# ## New section

# %% [markdown]
# *   python
# *   java
#
#
#
# 1.   python
# 2.   java
#
# vachan
#
# >vachanIndented block
#
#
# fhhkhj

# %% [markdown]
# *for* *maths*  *equations*

# %% [markdown]
# $ax^2bx+c=0$

# %% [markdown]
# $x1=\frac{a}{b}
# $

# %% [markdown]
# *completed*
